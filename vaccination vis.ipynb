# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Kaggle/covid_vaccine_statewise.csv')

# %%
df.head()
# Out:
#    Updated On  State  Total Individuals Vaccinated  Total Sessions Conducted  \
# 0  16-01-2021  India                       48276.0                    3455.0
# 1  17-01-2021  India                       58604.0                    8532.0
# 2  18-01-2021  India                       99449.0                   13611.0
# 3  19-01-2021  India                      195525.0                   17855.0
# 4  20-01-2021  India                      251280.0                   25472.0
#
#    Total Sites   First Dose Administered  Second Dose Administered  \
# 0        2957.0                  48276.0                       0.0
# 1        4954.0                  58604.0                       0.0
# 2        6583.0                  99449.0                       0.0
# 3        7951.0                 195525.0                       0.0
# 4       10504.0                 251280.0                       0.0
#
#    Male(Individuals Vaccinated)  Female(Individuals Vaccinated)  \
# ...

# %%
df.tail()
# Out:
#       Updated On        State  Total Individuals Vaccinated  \
# 5139  30-05-2021  West Bengal                    10547015.0
# 5140  31-05-2021  West Bengal                    10838457.0
# 5141  01-06-2021  West Bengal                           NaN
# 5142  02-06-2021  West Bengal                           NaN
# 5143  03-06-2021  West Bengal                           NaN
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 5139                  381157.0        1170.0               10547015.0
# 5140                  839415.0        2511.0               10838457.0
# 5141                       NaN           NaN                      NaN
# 5142                       NaN           NaN                      NaN
# 5143                       NaN           NaN                      NaN
#
#       Second Dose Administered  Male(Individuals Vaccinated)  \
# 5139                 3865954.0                     5871662.0
# ...

# %%
df.shape
# Out:
# (5144, 18)

# %%
df.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Individuals Vaccinated            120
# Total Sessions Conducted                120
# Total Sites                             120
# First Dose Administered                 120
# Second Dose Administered                120
# Male(Individuals Vaccinated)            120
# Female(Individuals Vaccinated)          120
# Transgender(Individuals Vaccinated)     120
# Total Covaxin Administered              120
# Total CoviShield Administered           120
# Total Sputnik V Administered           4744
# AEFI                                   2303
# 18-45 years (Age)                      2304
# 45-60 years (Age)                      2303
# 60+ years (Age)                        2303
# Total Doses Administered                114
# dtype: int64

# %%
print(df)
# Out:
#       Updated On        State  Total Individuals Vaccinated  \
# 0     16-01-2021        India                       48276.0
# 1     17-01-2021        India                       58604.0
# 2     18-01-2021        India                       99449.0
# 3     19-01-2021        India                      195525.0
# 4     20-01-2021        India                      251280.0
# ...          ...          ...                           ...
# 5139  30-05-2021  West Bengal                    10547015.0
# 5140  31-05-2021  West Bengal                    10838457.0
# 5141  01-06-2021  West Bengal                           NaN
# 5142  02-06-2021  West Bengal                           NaN
# 5143  03-06-2021  West Bengal                           NaN
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 0                       3455.0        2957.0                  48276.0
# 1                       8532.0        4954.0                  58604.0
# ...

# %%
df.plot()
plt.show()

# %%
df.shape
# Out:
# (5144, 18)

# %%
df.keys()
# Out:
# Index(['Updated On', 'State', 'Total Individuals Vaccinated',
#        'Total Sessions Conducted', 'Total Sites ', 'First Dose Administered',
#        'Second Dose Administered', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Covaxin Administered', 'Total CoviShield Administered',
#        'Total Sputnik V Administered', 'AEFI', '18-45 years (Age)',
#        '45-60 years (Age)', '60+ years (Age)', 'Total Doses Administered'],
#       dtype='object')

# %%
#plt.figure(figsize=(5,5))
#display(plt.plot(x,y))

#to permanently change fiure size
plt.rcParams['figure.figsize']=[8,8]

# %%
df.plot(kind='scatter',y='Total Doses Administered',x='Total Individuals Vaccinated')
# Out:
# <AxesSubplot:xlabel='Total Individuals Vaccinated', ylabel='Total Doses Administered'>

# %%
df.plot(kind='hist',x='Total Individuals Vaccinated')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='scatter',x="Male(Individuals Vaccinated)",y='Female(Individuals Vaccinated)')
# Out:
# <AxesSubplot:xlabel='Male(Individuals Vaccinated)', ylabel='Female(Individuals Vaccinated)'>

# %%
x=df['Total Covaxin Administered']
y=df['Total CoviShield Administered']
plt.plot(x,y)

# %%
#plt.scatter(x,y)
plt.figure(figsize=(10,10))
display(plt.plot(x,y))

# %%
p=df['Total Sessions Conducted']
q=df['Total Individuals Vaccinated']
plt.xlabel('Total Sessions Conducted')
plt.ylabel('Total Individuals Vaccinated')
plt.title('Total Sessions Conducted vs Total Individuals Vaccinated')
plt.plot(p,q)

# %%
plt.xlabel('Covaxin')
plt.ylabel('CoviShield')
plt.title('Vaccines: Covaxin vs CoviSheild')
#colors=['red','blue']
plt.scatter(p,q)

# %%
k=df['Total Covaxin Administered'][:4]

lbl=['A','B','C','D']
kex=[0,0,0,0.2]

plt.pie(k,explode=kex,labels=lbl)
plt.legend(title='Covaxin')
plt.show()

# %%
df.keys()
# Out:
# Index(['Updated On', 'State', 'Total Individuals Vaccinated',
#        'Total Sessions Conducted', 'Total Sites ', 'First Dose Administered',
#        'Second Dose Administered', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Covaxin Administered', 'Total CoviShield Administered',
#        'Total Sputnik V Administered', 'AEFI', '18-45 years (Age)',
#        '45-60 years (Age)', '60+ years (Age)', 'Total Doses Administered'],
#       dtype='object')

# %%
plt.pie(k)
plt.show()

# %%
plt.hist(p)
# Out:
# (array([4.925e+03, 1.800e+01, 1.000e+00, 5.000e+00, 6.000e+00, 1.200e+01,
#         1.300e+01, 2.000e+01, 1.600e+01, 8.000e+00]),
#  array([       0. ,  1134065.5,  2268131. ,  3402196.5,  4536262. ,
#          5670327.5,  6804393. ,  7938458.5,  9072524. , 10206589.5,
#         11340655. ]),
#  <BarContainer object of 10 artists>)
